# %% [markdown]
# ### Statistic Dataset

# %%
from collections import defaultdict
import glob
from tqdm import tqdm
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Medmention

# %%
mention_docid_dict = defaultdict(dict)
docids = []

data_dir = "/home/ju/Desktop/A-Metric-Learning-based-Method-for-Biomedical-Entity-Linking/data/processed/MedMention/st21pv/train"

files = glob.glob(os.path.join(data_dir, "*.context"))
label_freq = defaultdict(int)

for file_name in tqdm(files):

    mention_file = os.path.join(data_dir, os.path.basename(file_name).replace(".context", ".txt"))
    with open(mention_file, "r") as f:
        lines = f.read().split('\n')
        for line in lines: 
            line = line.split('||')
            mention = line[1].lower()
            label = line[0]
            label_freq[label] += 1
# Out:
# 100%|██████████| 2635/2635 [00:00<00:00, 6752.90it/s]

# %%
freq = list(label_freq.values())
freq = [x for x in freq if x <= 50]

t = pd.DataFrame(freq)
t.describe()
# Out:
#                   0
# count  18209.000000
# mean       4.634961
# std        6.498126
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        5.000000
# max       50.000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.hist(freq, bins=100)
plt.xlabel("Number of samples per entity")
plt.ylabel("Number of entities")
plt.savefig("st21pv_hist.jpg", format="jpg", bbox_inches="tight")
plt.show()

# %% [markdown]
# #### BC5CDR

# %%
mention_docid_dict = defaultdict(dict)
docids = []

data_dir = "/home/ju/Desktop/A-Metric-Learning-based-Method-for-Biomedical-Entity-Linking/data/processed/BC5CDR/train"

files = glob.glob(os.path.join(data_dir, "*.context"))
label_freq = defaultdict(int)

for file_name in tqdm(files):

    mention_file = os.path.join(data_dir, os.path.basename(file_name).replace(".context", ".txt"))
    with open(mention_file, "r") as f:
        lines = f.read().split('\n')
        for line in lines: 
            line = line.split('||')
            mention = line[1].lower()
            label = line[0]
            label_freq[label] += 1

import numpy as np
freq = list(label_freq.values())

freq = [x for x in freq if x <= 50]

t = pd.DataFrame(freq)
t.describe()

plt.figure(figsize=(8,5))
plt.hist(freq, bins=100)
plt.xlabel("Number of samples per entity")
plt.ylabel("Number of entities")
plt.savefig("bc5cdr_train_hist.jpg", format="jpg", bbox_inches="tight")
plt.show()
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 35827.32it/s]

# %%
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.pyplot as plt

# %%
import shutil

shutil.make_archive("medmention_train", "zip", "../dataset/processed/st21pv/train")
# Out:
# '/notebooks/MedMention/notebooks/medmention_train.zip'

# %%
import shutil

shutil.make_archive("bc5cdr_test", "zip", "../../BC5CDR/processed_dataset/test")
# Out:
# '/notebooks/MedMention/notebooks/bc5cdr_test.zip'

# %%
shutil.make_archive("best_all_samples", "zip", "../../BC5CDR/Untitled Folder")
# Out:
# '/notebooks/MedMention/notebooks/best_all_samples.zip'
